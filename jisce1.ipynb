# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_6312/451384764.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount("/content/drive")
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-81d03a8a-9ef7-4fd1-b7b6-b36ed57c2f61" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-81d03a8a-9ef7-4fd1-b7b6-b36ed57c2f61">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir-p~/.kaggle
# !cp kaggle.json~/.kaggle
# !chmod 600~/.kaggle.json
# Out:
# /bin/bash: line 1: mkdir-p~/.kaggle: No such file or directory
# cp: missing destination file operand after 'kaggle.json~/.kaggle'
# Try 'cp --help' for more information.
# chmod: missing operand after ‘600~/.kaggle.json’
# Try 'chmod --help' for more information.

# %%
# !kaggle datasets download -d sumanbera19/bengaluru-house-price-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/sumanbera19/bengaluru-house-price-dataset
# License(s): CC0-1.0
# ...
# 100% 194k/194k [00:00<00:00, 375kB/s]

# %%
import zipfile

# %%
with zipfile.ZipFile("bengaluru-house-price-dataset.zip") as z:
  z.extractall("HOUSE")

# %%
import numpy as np
import pandas as pd

# %%
data= pd.read_csv("/content/HOUSE/bengaluru_house_prices.csv")
df=pd.DataFrame(data)
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.shape
# Out:
# (13320, 9)

# %%
df.info
# Out:
# <bound method DataFrame.info of                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(6201)

# %%
df.size
# Out:
# 119880

# %%
df1=df.dropna()
df1.shape
# Out:
# (7496, 9)

# %%
a=df.isnull().sum()/df.shape[0]*100
a
# Out:
# area_type        0.000000
# availability     0.000000
# location         0.007508
# size             0.120120
# society         41.306306
# total_sqft       0.000000
# bath             0.548048
# balcony          4.572072
# price            0.000000
# dtype: float64

# %%
b=a[a>17].keys()
b
# Out:
# Index(['society'], dtype='object')

# %%
df.drop(b,axis=1,inplace=True)
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size total_sqft  bath  balcony   price
# 0          2 BHK       1056   2.0      1.0   39.07
# ...

# %%
cat_col=df.select_dtypes(include=["object"]).columns.tolist()
cat_col
# Out:
# ['area_type', 'availability', 'location', 'size', 'total_sqft']

# %%
num_col=df.select_dtypes(include=["int64","float64"]).columns.tolist()
num_col
# Out:
# ['bath', 'balcony', 'price']

# %%
from sklearn.impute import SimpleImputer

# %%
cat_clean=SimpleImputer(strategy="most_frequent")
num_clean=SimpleImputer(strategy="mean")

# %%
df[cat_col]=cat_clean.fit_transform(df[cat_col])
df[num_col]=num_clean.fit_transform(df[num_col])

# %%
df.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size total_sqft  bath   balcony   price
# 0          2 BHK       1056   2.0  1.000000   39.07
# ...

# %%
df["price"]=df["price"]*10000
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size total_sqft  bath   balcony         price
# 0          2 BHK       1056   2.0  1.000000  3.907000e+11
# ...

# %%
x = df['size'].apply(lambda x: int(x.split(' ')[0]))
x
# Out:
# 0        2
# 1        4
# 2        3
# 3        3
# 4        2
#         ..
# 13315    5
# 13316    4
# 13317    2
# 13318    4
# 13319    1
# Name: size, Length: 13320, dtype: int64

# %%
df.insert(4,"BHK",x)
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  BHK total_sqft  bath   balcony         price
# 0          2 BHK    2       1056   2.0  1.000000  3.907000e+11
# ...

# %%
def convert_sqft_to_num(x):
    if isinstance(x, float):
        return x
    if not isinstance(x, str):
        return None
    tokens = x.split('-')
    if len(tokens) == 2:
        return (float(tokens[0]) + float(tokens[1]))/2
    try:
        return float(x)
    except:
        return None

df['total_sqft'] = df['total_sqft'].apply(convert_sqft_to_num)
df['price_per_sqft'] = df['price'] / df['total_sqft']
display(df.head())
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    BHK  total_sqft  bath  balcony         price  price_per_sqft
# 0    2      1056.0   2.0      1.0  3.907000e+11    3.699811e+08
# 1    4      2600.0   5.0      3.0  1.200000e+12    4.615385e+08
# 2    3      1440.0   2.0      3.0  6.200000e+11    4.305556e+08
# 3    3      1521.0   3.0      1.0  9.500000e+11    6.245891e+08
# 4    2      1200.0   2.0      1.0  5.100000e+11    4.250000e+08

# %%
def check(x):
  try:
    float(x)
    return True
  except:
    return False

# %%
# Ensure df is defined. If you get a NameError, please re-run the cell where you loaded the CSV.
try:
    # Since total_sqft was converted to numeric in cell 25df4adb,
    # we check for any remaining nulls or non-numeric values.
    z = df[df['total_sqft'].isna()]
    display(z)
except NameError:
    print("Error: 'df' is not defined. Please run the data loading and preprocessing cells above first.")
# Out:
# Error: 'df' is not defined. Please run the data loading and preprocessing cells above first.

# %%
import pandas as pd
import numpy as np

# Re-loading the data to define 'df' again
try:
    data = pd.read_csv("/content/HOUSE/bengaluru_house_prices.csv")
    df = pd.DataFrame(data)
    print("Successfully re-defined 'df'. You can now run the preprocessing and analysis cells again.")
except FileNotFoundError:
    print("Dataset file not found. Please ensure the extraction cell (55tOvHPWWMJ7) was run successfully.")
# Out:
# Dataset file not found. Please ensure the extraction cell (55tOvHPWWMJ7) was run successfully.
